# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehsan-Roohi/DSMC_Python/blob/main/Shock_Tube_With_DCP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# --- DSMC CODE - V28.0 - User-selectable Collision Method ---
# This version adds the Deterministic Closest-Pair (DCP) collision method
# as a user-selectable option alongside the existing SBT method.

import numpy as np
import matplotlib.pyplot as plt
import numba
import time
from scipy.signal import savgol_filter
import pandas as pd
import warnings
from numba.core.errors import NumbaPerformanceWarning

# Suppress Numba performance warnings for cleaner output
warnings.simplefilter('ignore', category=NumbaPerformanceWarning)

# ===================================================================
# 1. Simulation Core
# ===================================================================
MASS_AR = 39.948e-3 / 6.022e23
KB = 1.380649e-23
D_REF_AR = 4.17e-10      # Diameter of Argon atom (m) for VHS
T_REF_AR = 273.0         # Reference Temperature for VHS
OMEGA_VHS = 0.81         # VHS model exponent

@numba.jit(nopython=True)
def calculate_vhs_cross_section_numba(vr_mag):
    """Calculates the collision cross-section using the VHS model."""
    if vr_mag < 1e-9: return 1e-30
    exponent = OMEGA_VHS - 0.5
    c_ref_sq = 2 * KB * T_REF_AR / MASS_AR
    gamma_val = 1.04533
    d_sq = (D_REF_AR**2) * ((c_ref_sq / vr_mag**2)**exponent) * (1 / gamma_val)
    return np.pi * d_sq

# --- Helper functions required for DCP method ---
@numba.jit(nopython=True)
def generate_pairs_and_weights_distance_based(indices_in_cell, x_all, distance_bias_power=2.0, epsilon=1e-10):
    """
    Generates all unique pairs within a cell and calculates their weights based on distance.
    Higher weight reflects closer distances.
    """
    Nc = len(indices_in_cell)
    if Nc < 2:
        return np.empty((0, 2), dtype=np.int32), np.empty(0, dtype=np.float64)

    max_pairs = Nc * (Nc - 1) // 2
    pairs = np.empty((max_pairs, 2), dtype=np.int32)
    weights = np.empty(max_pairs, dtype=np.float64)
    pair_count = 0

    for i in range(Nc):
        p_a_id = indices_in_cell[i]
        for k in range(i + 1, Nc):
            p_b_id = indices_in_cell[k]

            distance = np.abs(x_all[p_a_id] - x_all[p_b_id])
            denominator = (distance + epsilon)
            if denominator < 1e-12:
                denominator = 1e-12

            weight = 1.0 / (denominator**distance_bias_power)

            pairs[pair_count, 0] = p_a_id
            pairs[pair_count, 1] = p_b_id
            weights[pair_count] = weight
            pair_count += 1

    return pairs[:pair_count], weights[:pair_count]


# --- Collision Algorithms ---

@numba.jit(nopython=True)
def perform_collisions_sbt_subcell(particles, indices_in_cell, cell_start_x, cell_width, num_sub_cells, cell_vol, dt, fnum, dist_sum_array, count_array, main_cell_idx):
    """
    Performs collisions using the SBT method with adaptive sub-cells.
    Also accumulates data for SOF parameter calculation.
    """
    num_particles_in_main_cell = len(indices_in_cell)
    if num_particles_in_main_cell < 2: return

    num_sub_cells = max(1, num_sub_cells)
    sub_cell_width = cell_width / num_sub_cells
    sub_cell_groups = [[np.int64(x) for x in range(0)] for _ in range(num_sub_cells)]

    for p_idx in indices_in_cell:
        relative_pos = particles[p_idx, 0] - cell_start_x
        sub_cell_idx = int(relative_pos / sub_cell_width)
        if 0 <= sub_cell_idx < num_sub_cells:
            sub_cell_groups[sub_cell_idx].append(p_idx)

    sub_cell_vol = cell_vol / num_sub_cells
    if sub_cell_vol < 1e-30: return

    for sc_idx in range(num_sub_cells):
        indices_in_sub_cell = sub_cell_groups[sc_idx]
        num_particles_in_sub_cell = len(indices_in_sub_cell)
        if num_particles_in_sub_cell < 2: continue

        for i in range(num_particles_in_sub_cell - 1):
            p1_idx = indices_in_sub_cell[i]
            remaining_particles_count = num_particles_in_sub_cell - (i + 1)
            j_offset = np.random.randint(0, remaining_particles_count)
            j = i + 1 + j_offset
            p2_idx = indices_in_sub_cell[j]

            vr = particles[p1_idx, 1:4] - particles[p2_idx, 1:4]
            vr_mag = np.sqrt(np.sum(vr**2))
            if vr_mag < 1e-9: continue

            sigma_t = calculate_vhs_cross_section_numba(vr_mag)
            weighting_factor = float(remaining_particles_count)
            collision_prob = (weighting_factor * fnum * dt * sigma_t * vr_mag) / sub_cell_vol

            if np.random.rand() < collision_prob:
                dist = np.abs(particles[p1_idx, 0] - particles[p2_idx, 0])
                dist_sum_array[main_cell_idx] += dist
                count_array[main_cell_idx] += 1

                vcm = 0.5 * (particles[p1_idx, 1:4] + particles[p2_idx, 1:4])
                cos_chi = 2 * np.random.rand() - 1.0
                sin_chi = np.sqrt(1.0 - cos_chi**2)
                phi_chi = 2.0 * np.pi * np.random.rand()
                vr_prime = np.array([vr_mag * sin_chi * np.cos(phi_chi), vr_mag * sin_chi * np.sin(phi_chi), vr_mag * cos_chi])
                particles[p1_idx, 1:4] = vcm + 0.5 * vr_prime
                particles[p2_idx, 1:4] = vcm - 0.5 * vr_prime


@numba.jit(nopython=True)
def perform_collisions_dcp_numba(particles, indices_in_cell, cell_vol, dt, fnum,
                                 fractional_collisions_accumulator,
                                 dist_sum_array, count_array, cell_idx):
    """
    Performs collisions using the Deterministic Closest-Pair (DCP) method.
    Selects the closest pair for each potential collision.
    """
    num_particles_in_cell = len(indices_in_cell)
    if num_particles_in_cell < 2:
        return

    # Generate pairs and weights based on distance (higher weight for closer pairs)
    pairs, weights = generate_pairs_and_weights_distance_based(indices_in_cell, particles[:, 0])

    if len(pairs) == 0:
        return

    # Calculate the expected number of collisions (NTC method)
    sum_of_sigma_g = 0.0
    for i in range(len(pairs)):
        p_a_id, p_b_id = pairs[i]
        vr = particles[p_a_id, 1:4] - particles[p_b_id, 1:4]
        vr_mag = np.sqrt(np.sum(vr**2))
        if vr_mag > 1e-9:
            sigma_t_vhs = calculate_vhs_cross_section_numba(vr_mag)
            sum_of_sigma_g += sigma_t_vhs * vr_mag

    # Calculate total number of collisions to attempt this step
    expected_collisions_float = (0.5 * num_particles_in_cell * (num_particles_in_cell - 1)) * sum_of_sigma_g / (len(pairs) if len(pairs) > 0 else 1) * (fnum * dt / cell_vol)

    # Handle fractional collisions
    expected_collisions_float += fractional_collisions_accumulator[cell_idx]
    num_collisions_to_perform = int(np.floor(expected_collisions_float))
    fractional_collisions_accumulator[cell_idx] = expected_collisions_float - num_collisions_to_perform

    if num_collisions_to_perform <= 0:
        return

    # Perform collisions by deterministically selecting the closest pairs
    for _ in range(num_collisions_to_perform):
        if np.sum(weights) <= 0.0:
            break # No more valid pairs to select

        # Find the pair with the maximum weight (closest pair)
        selected_idx = np.argmax(weights)
        if weights[selected_idx] <= 0.0:
            break

        p_a_id, p_b_id = pairs[selected_idx]

        # --- VHS Collision Mechanics ---
        vr = particles[p_a_id, 1:4] - particles[p_b_id, 1:4]
        vr_mag = np.sqrt(np.sum(vr**2))

        if vr_mag < 1e-9:
            weights[selected_idx] = 0.0 # Mark as used even if no collision occurs
            continue

        # --- Accumulate data for SOF calculation ---
        dist = np.abs(particles[p_a_id, 0] - particles[p_b_id, 0])
        dist_sum_array[cell_idx] += dist
        count_array[cell_idx] += 1
        # --- End data accumulation ---

        vcm = 0.5 * (particles[p_a_id, 1:4] + particles[p_b_id, 1:4])
        cos_chi = 2 * np.random.rand() - 1.0
        sin_chi = np.sqrt(1.0 - cos_chi**2)
        phi_chi = 2.0 * np.pi * np.random.rand()
        vr_prime = np.array([vr_mag * sin_chi * np.cos(phi_chi), vr_mag * sin_chi * np.sin(phi_chi), vr_mag * cos_chi])

        particles[p_a_id, 1:4] = vcm + 0.5 * vr_prime
        particles[p_b_id, 1:4] = vcm - 0.5 * vr_prime

        # Set weight to zero to prevent re-selection in the same timestep
        weights[selected_idx] = 0.0


def run_dsmc_simulation(sim_params, collision_method):
    """Main DSMC simulation loop."""
    LX = sim_params['LX']; RHO_INIT = sim_params['RHO_INIT']; T_INIT = sim_params['T_INIT']
    NUM_CELLS_X = sim_params['NUM_CELLS_X']; PARTICLES_PER_CELL_INIT = sim_params['PARTICLES_PER_CELL_INIT']
    TOTAL_TIME = sim_params['TOTAL_TIME']; DT = sim_params['DT']
    MIN_PARTICLES_FOR_STATS = 2
    MAX_SUB_CELLS = sim_params['MAX_SUB_CELLS']
    ADAPTATION_INTERVAL = sim_params['ADAPTATION_INTERVAL']

    particles = initialize_shock_tube(sim_params)

    N_DENSITY_REAL = RHO_INIT / MASS_AR
    CELL_VOLUME_CONCEPTUAL = (LX / NUM_CELLS_X) * ((LX/10) * (LX/10))
    FNUM = (N_DENSITY_REAL * CELL_VOLUME_CONCEPTUAL) / PARTICLES_PER_CELL_INIT
    NUM_STEPS = int(TOTAL_TIME / DT)

    sample_points_in_time = np.linspace(0, TOTAL_TIME, 5)
    sample_steps = {int(round(t / DT)) for t in sample_points_in_time}
    sample_steps.add(NUM_STEPS)

    results_history = {}
    cell_width = LX / NUM_CELLS_X

    initial_props = sample_properties(particles, NUM_CELLS_X, cell_width, FNUM, CELL_VOLUME_CONCEPTUAL, MIN_PARTICLES_FOR_STATS)
    initial_props['sof'] = np.full(NUM_CELLS_X, np.nan)
    initial_props['subcell_mfp_ratio'] = np.full(NUM_CELLS_X, np.nan)
    results_history[0.0] = initial_props

    subcell_config = np.ones(NUM_CELLS_X, dtype=np.int32)
    accumulated_dist_sum = np.zeros(NUM_CELLS_X, dtype=np.float64)
    accumulated_collision_count = np.zeros(NUM_CELLS_X, dtype=np.int64)
    # Add accumulator for DCP fractional collisions
    fractional_collisions_accumulator = np.zeros(NUM_CELLS_X, dtype=np.float64)

    current_step = 0
    while current_step < NUM_STEPS:
        sum_cell_counts = np.zeros(NUM_CELLS_X, dtype=np.int64)
        steps_in_block = min(ADAPTATION_INTERVAL, NUM_STEPS - current_step)

        for _ in range(steps_in_block):
            current_step += 1
            if current_step > NUM_STEPS: break

            particles[:, 0] += particles[:, 1] * DT
            hit_left = particles[:, 0] < 0; particles[hit_left, 1] *= -1; particles[hit_left, 0] *= -1
            hit_right = particles[:, 0] > LX; particles[hit_right, 1] *= -1; particles[hit_right, 0] = 2 * LX - particles[hit_right, 0]

            cell_indices = (particles[:, 0] / cell_width).astype(np.int64)
            cell_indices = np.clip(cell_indices, 0, NUM_CELLS_X - 1)
            sorted_particle_indices = np.argsort(cell_indices)
            cell_counts = np.bincount(cell_indices, minlength=NUM_CELLS_X)

            sum_cell_counts += cell_counts
            cell_start_indices = np.concatenate((np.array([0], dtype=np.int64), np.cumsum(cell_counts[:-1])))

            for i in range(NUM_CELLS_X):
                if cell_counts[i] > 1:
                    start = cell_start_indices[i]; end = start + cell_counts[i]
                    indices_in_cell_i = sorted_particle_indices[start:end]
                    cell_start_x = i * cell_width

                    # --- SELECT COLLISION METHOD ---
                    if collision_method == 'SBT':
                        perform_collisions_sbt_subcell(particles, indices_in_cell_i, cell_start_x, cell_width, subcell_config[i], CELL_VOLUME_CONCEPTUAL, DT, FNUM, accumulated_dist_sum, accumulated_collision_count, i)
                    elif collision_method == 'DCP':
                        perform_collisions_dcp_numba(particles, indices_in_cell_i, CELL_VOLUME_CONCEPTUAL, DT, FNUM, fractional_collisions_accumulator, accumulated_dist_sum, accumulated_collision_count, i)
                    # --- END METHOD SELECTION ---

            if current_step in sample_steps:
                time_key = current_step * DT
                if abs(time_key) > 1e-15:
                    props = sample_properties(particles, NUM_CELLS_X, cell_width, FNUM, CELL_VOLUME_CONCEPTUAL, MIN_PARTICLES_FOR_STATS)
                    avg_dist = np.full(NUM_CELLS_X, np.nan, dtype=np.float64)
                    valid_counts = accumulated_collision_count > 0
                    avg_dist[valid_counts] = accumulated_dist_sum[valid_counts] / accumulated_collision_count[valid_counts]

                    temp = props['temperature']
                    density = props['density']
                    mfp = np.full_like(temp, np.nan)
                    for cell_idx in range(NUM_CELLS_X):
                        if not np.isnan(temp[cell_idx]) and not np.isnan(density[cell_idx]) and temp[cell_idx] > 0 and density[cell_idx] > 0:
                            avg_vr = np.sqrt(16 * KB * temp[cell_idx] / (np.pi * MASS_AR))
                            avg_sigma = calculate_vhs_cross_section_numba(avg_vr)
                            mfp[cell_idx] = 1.0 / (density[cell_idx] * avg_sigma)

                    with np.errstate(divide='ignore', invalid='ignore'):
                        sof = avg_dist / mfp
                    props['sof'] = sof

                    subcell_size = cell_width / subcell_config
                    with np.errstate(divide='ignore', invalid='ignore'):
                        subcell_mfp_ratio = subcell_size / mfp
                    props['subcell_mfp_ratio'] = subcell_mfp_ratio

                    results_history[time_key] = props
                    accumulated_dist_sum.fill(0)
                    accumulated_collision_count.fill(0)

        avg_cell_counts = sum_cell_counts / steps_in_block
        max_avg_count = np.max(avg_cell_counts)
        if max_avg_count > 1e-9:
            normalized_density = avg_cell_counts / max_avg_count
            adaptive_rule = 1.0 - normalized_density
            subcell_config = np.clip(1 + ((MAX_SUB_CELLS - 1) * adaptive_rule).astype(np.int32), 1, MAX_SUB_CELLS)

    return results_history

def initialize_shock_tube(params):
    """Initializes particle positions and velocities."""
    num_cells = params['NUM_CELLS_X']; lx = params['LX']
    ppc_left = params['PARTICLES_PER_CELL_INIT']; t_left = params['T_INIT']
    rho_ratio = params['RHO_RATIO']
    ppc_right = int(ppc_left / rho_ratio)
    if ppc_right < 1: ppc_right = 1

    num_cells_left = num_cells // 2
    num_cells_right = num_cells - num_cells_left
    total_particles = (ppc_left * num_cells_left) + (ppc_right * num_cells_right)
    particles = np.zeros((total_particles, 4))

    cell_width = lx / num_cells
    v_thermal_std = np.sqrt(KB * t_left / MASS_AR)

    current_pos = 0
    for i in range(num_cells_left):
        start_idx = current_pos; end_idx = start_idx + ppc_left
        particles[start_idx:end_idx, 0] = i * cell_width + np.random.rand(ppc_left) * cell_width
        particles[start_idx:end_idx, 1:4] = np.random.normal(0, v_thermal_std, (ppc_left, 3))
        current_pos = end_idx
    for i in range(num_cells_left, num_cells):
        start_idx = current_pos; end_idx = start_idx + ppc_right
        particles[start_idx:end_idx, 0] = i * cell_width + np.random.rand(ppc_right) * cell_width
        particles[start_idx:end_idx, 1:4] = np.random.normal(0, v_thermal_std, (ppc_right, 3))
        current_pos = end_idx

    print(f"Initialized {total_particles} particles for Shock Tube problem.")
    return particles

def sample_properties(particles_state, num_cells, cell_width, fnum, cell_vol, min_parts):
    """Samples macroscopic properties from particle data."""
    density_profile = np.full(num_cells, np.nan)
    velocity_profile = np.full(num_cells, np.nan)
    temp_profile = np.full(num_cells, np.nan)

    cell_indices = (particles_state[:, 0] / cell_width).astype(np.int64)
    cell_indices = np.clip(cell_indices, 0, num_cells - 1)

    sorted_indices = np.argsort(cell_indices)
    counts = np.bincount(cell_indices, minlength=num_cells)
    starts = np.concatenate((np.array([0], dtype=np.int64), np.cumsum(counts[:-1])))

    for i in range(num_cells):
        num_in_cell = counts[i]
        if num_in_cell > 0:
            density_profile[i] = num_in_cell * fnum / cell_vol
        if num_in_cell >= min_parts:
            indices_in_cell_i = sorted_indices[starts[i]:starts[i]+num_in_cell]
            cell_velocities = particles_state[indices_in_cell_i, 1:4]
            mean_vel_cell = np.mean(cell_velocities, axis=0)
            velocity_profile[i] = mean_vel_cell[0]

            thermal_vel_sq = np.sum((cell_velocities - mean_vel_cell)**2)
            if num_in_cell > 1:
                temp_profile[i] = (MASS_AR * thermal_vel_sq) / (3 * KB * (num_in_cell - 1))
            else:
                temp_profile[i] = 0.0

    return {'density': density_profile, 'velocity': velocity_profile, 'temperature': temp_profile}

# ===================================================================
# 2. Main Execution Block
# ===================================================================
if __name__ == "__main__":
    SIMULATION_PARAMS = {
        'LX': 1.0e-6, 'RHO_INIT': 1.78, 'T_INIT': 273.0,
        'NUM_CELLS_X': 4400,
        'DT': 6.744e-13,
        'PARTICLES_PER_CELL_INIT': 10,
        'TOTAL_TIME': 0.4e-9,
        'RHO_RATIO': 10.0,
        'MAX_SUB_CELLS': 20,
        'ADAPTATION_INTERVAL': 50,
    }
    NUM_ENSEMBLE_RUNS = 2500

    # <<< MODIFIED: Interactive choice for collision method >>>
    while True:
        choice = input("Please choose the collision method:\n  [1] Simplified Bernoulli Trials (SBT)\n  [2] Deterministic Closest-Pair (DCP)\nEnter choice (1 or 2): ")
        if choice == '1':
            SELECTED_METHOD = 'SBT'
            break
        elif choice == '2':
            SELECTED_METHOD = 'DCP'
            break
        else:
            print("Invalid input. Please enter 1 or 2.")


    print(f"--- شروع اجرای نهایی با محاسبه SOF ---")
    print(f"--- Using Collision Method: {SELECTED_METHOD} ---")
    print(f"--- Parameters: NUM_CELLS_X={SIMULATION_PARAMS['NUM_CELLS_X']}, DT={SIMULATION_PARAMS['DT']:.4e}, PPC={SIMULATION_PARAMS['PARTICLES_PER_CELL_INIT']} ---")

    all_results = []
    start_time_total = time.time()
    for i in range(NUM_ENSEMBLE_RUNS):
        np.random.seed(int(time.time()) + i)
        # Pass the selected method to the simulation function
        single_run_history = run_dsmc_simulation(SIMULATION_PARAMS, SELECTED_METHOD)
        all_results.append(single_run_history)
        print(f"--- اجرای {i+1}/{NUM_ENSEMBLE_RUNS} تمام شد. زمان سپری شده: {time.time() - start_time_total:.2f} ثانیه ---")

    sample_times = sorted(all_results[0].keys())
    averaged_results = {t: {} for t in sample_times}

    data_keys_to_average = ['density', 'velocity', 'temperature', 'sof', 'subcell_mfp_ratio']

    for t in sample_times:
        for key in data_keys_to_average:
            all_data_for_t_and_key = [run[t][key] for run in all_results if t in run and key in run[t]]
            if all_data_for_t_and_key:
                averaged_results[t][key] = np.nanmean(np.array(all_data_for_t_and_key), axis=0)

    cell_width = SIMULATION_PARAMS['LX'] / SIMULATION_PARAMS['NUM_CELLS_X']
    cell_centers = (np.arange(SIMULATION_PARAMS['NUM_CELLS_X']) + 0.5) * cell_width

    # --- PLOTTING ---
    plt.rcParams.update({
        'font.size': 28, 'axes.labelsize': 30, 'axes.titlesize': 32,
        'xtick.labelsize': 28, 'ytick.labelsize': 28, 'legend.fontsize': 26
    })

    fig, axes = plt.subplots(3, 2, figsize=(24, 30), sharex=True)
    axes_flat = axes.flatten()

    fig.suptitle(f"DSMC Shock Tube (Method: {SELECTED_METHOD}, N_runs={NUM_ENSEMBLE_RUNS}, PPC={SIMULATION_PARAMS['PARTICLES_PER_CELL_INIT']})", fontsize=34)

    plot_info = {
        'Density': {'data_key': 'density', 'ax': axes_flat[0], 'ylabel': 'Number Density ($m^{-3}$)'},
        'Velocity': {'data_key': 'velocity', 'ax': axes_flat[1], 'ylabel': 'Bulk Velocity (m/s)'},
        'Temperature': {'data_key': 'temperature', 'ax': axes_flat[2], 'ylabel': 'Temperature (K)'},
        'SOF': {'data_key': 'sof', 'ax': axes_flat[3], 'ylabel': 'SOF Ratio'},
        'Subcell/MFP': {'data_key': 'subcell_mfp_ratio', 'ax': axes_flat[4], 'ylabel': r'Subcell $\Delta x$ / MFP'}
    }

    for name, p_info in plot_info.items():
        ax = p_info['ax']
        for t in sample_times:
            if t in averaged_results and p_info['data_key'] in averaged_results[t]:
                s_data = pd.Series(averaged_results[t][p_info['data_key']])
                valid_indices = ~s_data.isna()
                label_text = f't = {t*1e9:.2f} ns'
                line_style = '--' if abs(t) < 1e-12 else '-'

                if np.sum(valid_indices) > 0:
                    if name in ['Velocity', 'Temperature', 'SOF', 'Subcell/MFP'] and np.sum(valid_indices) > 51:
                        smoothed_data = savgol_filter(s_data[valid_indices], window_length=51, polyorder=2)
                        ax.plot(cell_centers[valid_indices], smoothed_data, linestyle=line_style, label=label_text)
                    else:
                        ax.plot(cell_centers[valid_indices], s_data[valid_indices], linestyle=line_style, label=label_text)

        ax.set_xlabel('Position x (m)')
        ax.set_ylabel(p_info['ylabel'])
        ax.set_title(f"{name} Profile")
        ax.grid(True, linestyle=':')
        ax.legend()

    fig.delaxes(axes_flat[5]) # Hide the unused subplot
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig(f"dsmc_final_results_{SELECTED_METHOD}.eps", format='eps')
    plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 1/2500 تمام شد. زمان سپری شده: 9.96 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2/2500 تمام شد. زمان سپری شده: 18.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 3/2500 تمام شد. زمان سپری شده: 27.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 4/2500 تمام شد. زمان سپری شده: 36.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 5/2500 تمام شد. زمان سپری شده: 45.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 6/2500 تمام شد. زمان سپری شده: 54.22 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 7/2500 تمام شد. زمان سپری شده: 63.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 8/2500 تمام شد. زمان سپری شده: 72.05 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 9/2500 تمام شد. زمان سپری شده: 80.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 10/2500 تمام شد. زمان سپری شده: 89.63 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 11/2500 تمام شد. زمان سپری شده: 98.52 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 12/2500 تمام شد. زمان سپری شده: 107.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 13/2500 تمام شد. زمان سپری شده: 116.23 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 14/2500 تمام شد. زمان سپری شده: 125.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 15/2500 تمام شد. زمان سپری شده: 133.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 16/2500 تمام شد. زمان سپری شده: 142.63 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 17/2500 تمام شد. زمان سپری شده: 151.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 18/2500 تمام شد. زمان سپری شده: 160.30 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 19/2500 تمام شد. زمان سپری شده: 169.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 20/2500 تمام شد. زمان سپری شده: 178.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 21/2500 تمام شد. زمان سپری شده: 186.85 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 22/2500 تمام شد. زمان سپری شده: 195.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 23/2500 تمام شد. زمان سپری شده: 204.42 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 24/2500 تمام شد. زمان سپری شده: 213.23 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 25/2500 تمام شد. زمان سپری شده: 222.07 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 26/2500 تمام شد. زمان سپری شده: 230.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 27/2500 تمام شد. زمان سپری شده: 239.70 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 28/2500 تمام شد. زمان سپری شده: 248.47 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 29/2500 تمام شد. زمان سپری شده: 257.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 30/2500 تمام شد. زمان سپری شده: 266.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 31/2500 تمام شد. زمان سپری شده: 275.01 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 32/2500 تمام شد. زمان سپری شده: 283.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 33/2500 تمام شد. زمان سپری شده: 292.75 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 34/2500 تمام شد. زمان سپری شده: 301.55 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 35/2500 تمام شد. زمان سپری شده: 310.41 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 36/2500 تمام شد. زمان سپری شده: 319.25 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 37/2500 تمام شد. زمان سپری شده: 328.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 38/2500 تمام شد. زمان سپری شده: 336.81 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 39/2500 تمام شد. زمان سپری شده: 345.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 40/2500 تمام شد. زمان سپری شده: 354.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 41/2500 تمام شد. زمان سپری شده: 363.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 42/2500 تمام شد. زمان سپری شده: 372.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 43/2500 تمام شد. زمان سپری شده: 380.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 44/2500 تمام شد. زمان سپری شده: 389.86 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 45/2500 تمام شد. زمان سپری شده: 398.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 46/2500 تمام شد. زمان سپری شده: 407.42 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 47/2500 تمام شد. زمان سپری شده: 416.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 48/2500 تمام شد. زمان سپری شده: 424.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 49/2500 تمام شد. زمان سپری شده: 433.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 50/2500 تمام شد. زمان سپری شده: 442.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 51/2500 تمام شد. زمان سپری شده: 451.51 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 52/2500 تمام شد. زمان سپری شده: 460.29 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 53/2500 تمام شد. زمان سپری شده: 469.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 54/2500 تمام شد. زمان سپری شده: 477.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 55/2500 تمام شد. زمان سپری شده: 486.73 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 56/2500 تمام شد. زمان سپری شده: 495.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 57/2500 تمام شد. زمان سپری شده: 504.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 58/2500 تمام شد. زمان سپری شده: 513.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 59/2500 تمام شد. زمان سپری شده: 521.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 60/2500 تمام شد. زمان سپری شده: 530.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 61/2500 تمام شد. زمان سپری شده: 539.54 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 62/2500 تمام شد. زمان سپری شده: 548.38 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 63/2500 تمام شد. زمان سپری شده: 557.16 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 64/2500 تمام شد. زمان سپری شده: 565.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 65/2500 تمام شد. زمان سپری شده: 574.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 66/2500 تمام شد. زمان سپری شده: 583.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 67/2500 تمام شد. زمان سپری شده: 592.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 68/2500 تمام شد. زمان سپری شده: 601.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 69/2500 تمام شد. زمان سپری شده: 609.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 70/2500 تمام شد. زمان سپری شده: 618.74 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 71/2500 تمام شد. زمان سپری شده: 627.56 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 72/2500 تمام شد. زمان سپری شده: 636.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 73/2500 تمام شد. زمان سپری شده: 645.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 74/2500 تمام شد. زمان سپری شده: 653.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 75/2500 تمام شد. زمان سپری شده: 662.75 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 76/2500 تمام شد. زمان سپری شده: 671.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 77/2500 تمام شد. زمان سپری شده: 680.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 78/2500 تمام شد. زمان سپری شده: 689.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 79/2500 تمام شد. زمان سپری شده: 698.04 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 80/2500 تمام شد. زمان سپری شده: 706.86 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 81/2500 تمام شد. زمان سپری شده: 715.63 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 82/2500 تمام شد. زمان سپری شده: 724.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 83/2500 تمام شد. زمان سپری شده: 733.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 84/2500 تمام شد. زمان سپری شده: 742.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 85/2500 تمام شد. زمان سپری شده: 750.89 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 86/2500 تمام شد. زمان سپری شده: 759.62 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 87/2500 تمام شد. زمان سپری شده: 768.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 88/2500 تمام شد. زمان سپری شده: 777.24 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 89/2500 تمام شد. زمان سپری شده: 786.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 90/2500 تمام شد. زمان سپری شده: 794.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 91/2500 تمام شد. زمان سپری شده: 803.69 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 92/2500 تمام شد. زمان سپری شده: 812.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 93/2500 تمام شد. زمان سپری شده: 821.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 94/2500 تمام شد. زمان سپری شده: 830.13 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 95/2500 تمام شد. زمان سپری شده: 838.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 96/2500 تمام شد. زمان سپری شده: 847.70 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 97/2500 تمام شد. زمان سپری شده: 856.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 98/2500 تمام شد. زمان سپری شده: 865.41 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 99/2500 تمام شد. زمان سپری شده: 874.31 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 100/2500 تمام شد. زمان سپری شده: 883.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 101/2500 تمام شد. زمان سپری شده: 891.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 102/2500 تمام شد. زمان سپری شده: 900.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 103/2500 تمام شد. زمان سپری شده: 909.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 104/2500 تمام شد. زمان سپری شده: 918.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 105/2500 تمام شد. زمان سپری شده: 927.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 106/2500 تمام شد. زمان سپری شده: 935.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 107/2500 تمام شد. زمان سپری شده: 944.73 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 108/2500 تمام شد. زمان سپری شده: 953.51 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 109/2500 تمام شد. زمان سپری شده: 962.36 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 110/2500 تمام شد. زمان سپری شده: 971.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 111/2500 تمام شد. زمان سپری شده: 980.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 112/2500 تمام شد. زمان سپری شده: 988.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 113/2500 تمام شد. زمان سپری شده: 997.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 114/2500 تمام شد. زمان سپری شده: 1006.42 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 115/2500 تمام شد. زمان سپری شده: 1015.22 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 116/2500 تمام شد. زمان سپری شده: 1024.05 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 117/2500 تمام شد. زمان سپری شده: 1032.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 118/2500 تمام شد. زمان سپری شده: 1041.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 119/2500 تمام شد. زمان سپری شده: 1050.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 120/2500 تمام شد. زمان سپری شده: 1059.16 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 121/2500 تمام شد. زمان سپری شده: 1068.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 122/2500 تمام شد. زمان سپری شده: 1076.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 123/2500 تمام شد. زمان سپری شده: 1085.69 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 124/2500 تمام شد. زمان سپری شده: 1094.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 125/2500 تمام شد. زمان سپری شده: 1103.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 126/2500 تمام شد. زمان سپری شده: 1112.01 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 127/2500 تمام شد. زمان سپری شده: 1120.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 128/2500 تمام شد. زمان سپری شده: 1129.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 129/2500 تمام شد. زمان سپری شده: 1138.41 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 130/2500 تمام شد. زمان سپری شده: 1147.29 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 131/2500 تمام شد. زمان سپری شده: 1156.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 132/2500 تمام شد. زمان سپری شده: 1164.90 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 133/2500 تمام شد. زمان سپری شده: 1173.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 134/2500 تمام شد. زمان سپری شده: 1182.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 135/2500 تمام شد. زمان سپری شده: 1191.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 136/2500 تمام شد. زمان سپری شده: 1200.10 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 137/2500 تمام شد. زمان سپری شده: 1208.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 138/2500 تمام شد. زمان سپری شده: 1217.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 139/2500 تمام شد. زمان سپری شده: 1226.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 140/2500 تمام شد. زمان سپری شده: 1235.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 141/2500 تمام شد. زمان سپری شده: 1243.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 142/2500 تمام شد. زمان سپری شده: 1252.82 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 143/2500 تمام شد. زمان سپری شده: 1261.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 144/2500 تمام شد. زمان سپری شده: 1270.48 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 145/2500 تمام شد. زمان سپری شده: 1279.24 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 146/2500 تمام شد. زمان سپری شده: 1288.07 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 147/2500 تمام شد. زمان سپری شده: 1296.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 148/2500 تمام شد. زمان سپری شده: 1305.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 149/2500 تمام شد. زمان سپری شده: 1314.45 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 150/2500 تمام شد. زمان سپری شده: 1323.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 151/2500 تمام شد. زمان سپری شده: 1332.01 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 152/2500 تمام شد. زمان سپری شده: 1340.81 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 153/2500 تمام شد. زمان سپری شده: 1349.59 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 154/2500 تمام شد. زمان سپری شده: 1358.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 155/2500 تمام شد. زمان سپری شده: 1367.18 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 156/2500 تمام شد. زمان سپری شده: 1375.96 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 157/2500 تمام شد. زمان سپری شده: 1384.82 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 158/2500 تمام شد. زمان سپری شده: 1393.59 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 159/2500 تمام شد. زمان سپری شده: 1402.38 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 160/2500 تمام شد. زمان سپری شده: 1411.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 161/2500 تمام شد. زمان سپری شده: 1419.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 162/2500 تمام شد. زمان سپری شده: 1428.74 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 163/2500 تمام شد. زمان سپری شده: 1437.51 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 164/2500 تمام شد. زمان سپری شده: 1446.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 165/2500 تمام شد. زمان سپری شده: 1455.10 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 166/2500 تمام شد. زمان سپری شده: 1463.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 167/2500 تمام شد. زمان سپری شده: 1472.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 168/2500 تمام شد. زمان سپری شده: 1481.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 169/2500 تمام شد. زمان سپری شده: 1490.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 170/2500 تمام شد. زمان سپری شده: 1499.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 171/2500 تمام شد. زمان سپری شده: 1507.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 172/2500 تمام شد. زمان سپری شده: 1516.74 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 173/2500 تمام شد. زمان سپری شده: 1525.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 174/2500 تمام شد. زمان سپری شده: 1534.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 175/2500 تمام شد. زمان سپری شده: 1543.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 176/2500 تمام شد. زمان سپری شده: 1551.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 177/2500 تمام شد. زمان سپری شده: 1560.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 178/2500 تمام شد. زمان سپری شده: 1569.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 179/2500 تمام شد. زمان سپری شده: 1578.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 180/2500 تمام شد. زمان سپری شده: 1587.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 181/2500 تمام شد. زمان سپری شده: 1595.81 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 182/2500 تمام شد. زمان سپری شده: 1604.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 183/2500 تمام شد. زمان سپری شده: 1613.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 184/2500 تمام شد. زمان سپری شده: 1622.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 185/2500 تمام شد. زمان سپری شده: 1630.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 186/2500 تمام شد. زمان سپری شده: 1639.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 187/2500 تمام شد. زمان سپری شده: 1648.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 188/2500 تمام شد. زمان سپری شده: 1657.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 189/2500 تمام شد. زمان سپری شده: 1666.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 190/2500 تمام شد. زمان سپری شده: 1675.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 191/2500 تمام شد. زمان سپری شده: 1683.81 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 192/2500 تمام شد. زمان سپری شده: 1692.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 193/2500 تمام شد. زمان سپری شده: 1701.37 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 194/2500 تمام شد. زمان سپری شده: 1710.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 195/2500 تمام شد. زمان سپری شده: 1718.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 196/2500 تمام شد. زمان سپری شده: 1727.78 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 197/2500 تمام شد. زمان سپری شده: 1736.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 198/2500 تمام شد. زمان سپری شده: 1745.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 199/2500 تمام شد. زمان سپری شده: 1754.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 200/2500 تمام شد. زمان سپری شده: 1762.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 201/2500 تمام شد. زمان سپری شده: 1771.70 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 202/2500 تمام شد. زمان سپری شده: 1780.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 203/2500 تمام شد. زمان سپری شده: 1789.22 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 204/2500 تمام شد. زمان سپری شده: 1798.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 205/2500 تمام شد. زمان سپری شده: 1806.82 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 206/2500 تمام شد. زمان سپری شده: 1815.56 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 207/2500 تمام شد. زمان سپری شده: 1824.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 208/2500 تمام شد. زمان سپری شده: 1833.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 209/2500 تمام شد. زمان سپری شده: 1841.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 210/2500 تمام شد. زمان سپری شده: 1850.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 211/2500 تمام شد. زمان سپری شده: 1859.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 212/2500 تمام شد. زمان سپری شده: 1868.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 213/2500 تمام شد. زمان سپری شده: 1877.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 214/2500 تمام شد. زمان سپری شده: 1885.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 215/2500 تمام شد. زمان سپری شده: 1894.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 216/2500 تمام شد. زمان سپری شده: 1903.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 217/2500 تمام شد. زمان سپری شده: 1912.18 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 218/2500 تمام شد. زمان سپری شده: 1920.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 219/2500 تمام شد. زمان سپری شده: 1929.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 220/2500 تمام شد. زمان سپری شده: 1938.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 221/2500 تمام شد. زمان سپری شده: 1947.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 222/2500 تمام شد. زمان سپری شده: 1956.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 223/2500 تمام شد. زمان سپری شده: 1964.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 224/2500 تمام شد. زمان سپری شده: 1973.85 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 225/2500 تمام شد. زمان سپری شده: 1982.59 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 226/2500 تمام شد. زمان سپری شده: 1991.37 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 227/2500 تمام شد. زمان سپری شده: 2000.15 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 228/2500 تمام شد. زمان سپری شده: 2008.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 229/2500 تمام شد. زمان سپری شده: 2017.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 230/2500 تمام شد. زمان سپری شده: 2026.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 231/2500 تمام شد. زمان سپری شده: 2035.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 232/2500 تمام شد. زمان سپری شده: 2044.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 233/2500 تمام شد. زمان سپری شده: 2052.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 234/2500 تمام شد. زمان سپری شده: 2061.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 235/2500 تمام شد. زمان سپری شده: 2070.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 236/2500 تمام شد. زمان سپری شده: 2079.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 237/2500 تمام شد. زمان سپری شده: 2087.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 238/2500 تمام شد. زمان سپری شده: 2096.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 239/2500 تمام شد. زمان سپری شده: 2105.53 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 240/2500 تمام شد. زمان سپری شده: 2114.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 241/2500 تمام شد. زمان سپری شده: 2123.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 242/2500 تمام شد. زمان سپری شده: 2131.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 243/2500 تمام شد. زمان سپری شده: 2140.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 244/2500 تمام شد. زمان سپری شده: 2149.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 245/2500 تمام شد. زمان سپری شده: 2158.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 246/2500 تمام شد. زمان سپری شده: 2167.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 247/2500 تمام شد. زمان سپری شده: 2175.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 248/2500 تمام شد. زمان سپری شده: 2184.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 249/2500 تمام شد. زمان سپری شده: 2193.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 250/2500 تمام شد. زمان سپری شده: 2202.23 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 251/2500 تمام شد. زمان سپری شده: 2210.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 252/2500 تمام شد. زمان سپری شده: 2219.81 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 253/2500 تمام شد. زمان سپری شده: 2228.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 254/2500 تمام شد. زمان سپری شده: 2237.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 255/2500 تمام شد. زمان سپری شده: 2246.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 256/2500 تمام شد. زمان سپری شده: 2255.05 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 257/2500 تمام شد. زمان سپری شده: 2263.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 258/2500 تمام شد. زمان سپری شده: 2272.69 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 259/2500 تمام شد. زمان سپری شده: 2281.45 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 260/2500 تمام شد. زمان سپری شده: 2290.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 261/2500 تمام شد. زمان سپری شده: 2299.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 262/2500 تمام شد. زمان سپری شده: 2307.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 263/2500 تمام شد. زمان سپری شده: 2316.55 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 264/2500 تمام شد. زمان سپری شده: 2325.31 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 265/2500 تمام شد. زمان سپری شده: 2334.10 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 266/2500 تمام شد. زمان سپری شده: 2342.89 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 267/2500 تمام شد. زمان سپری شده: 2351.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 268/2500 تمام شد. زمان سپری شده: 2360.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 269/2500 تمام شد. زمان سپری شده: 2369.18 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 270/2500 تمام شد. زمان سپری شده: 2378.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 271/2500 تمام شد. زمان سپری شده: 2386.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 272/2500 تمام شد. زمان سپری شده: 2395.54 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 273/2500 تمام شد. زمان سپری شده: 2404.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 274/2500 تمام شد. زمان سپری شده: 2413.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 275/2500 تمام شد. زمان سپری شده: 2422.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 276/2500 تمام شد. زمان سپری شده: 2430.75 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 277/2500 تمام شد. زمان سپری شده: 2439.53 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 278/2500 تمام شد. زمان سپری شده: 2448.30 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 279/2500 تمام شد. زمان سپری شده: 2457.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 280/2500 تمام شد. زمان سپری شده: 2465.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 281/2500 تمام شد. زمان سپری شده: 2474.69 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 282/2500 تمام شد. زمان سپری شده: 2483.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 283/2500 تمام شد. زمان سپری شده: 2492.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 284/2500 تمام شد. زمان سپری شده: 2500.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 285/2500 تمام شد. زمان سپری شده: 2509.73 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 286/2500 تمام شد. زمان سپری شده: 2518.58 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 287/2500 تمام شد. زمان سپری شده: 2527.38 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 288/2500 تمام شد. زمان سپری شده: 2536.15 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 289/2500 تمام شد. زمان سپری شده: 2544.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 290/2500 تمام شد. زمان سپری شده: 2553.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 291/2500 تمام شد. زمان سپری شده: 2562.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 292/2500 تمام شد. زمان سپری شده: 2571.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 293/2500 تمام شد. زمان سپری شده: 2579.90 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 294/2500 تمام شد. زمان سپری شده: 2588.62 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 295/2500 تمام شد. زمان سپری شده: 2597.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 296/2500 تمام شد. زمان سپری شده: 2606.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 297/2500 تمام شد. زمان سپری شده: 2614.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 298/2500 تمام شد. زمان سپری شده: 2623.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 299/2500 تمام شد. زمان سپری شده: 2632.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 300/2500 تمام شد. زمان سپری شده: 2641.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 301/2500 تمام شد. زمان سپری شده: 2650.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 302/2500 تمام شد. زمان سپری شده: 2658.77 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 303/2500 تمام شد. زمان سپری شده: 2667.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 304/2500 تمام شد. زمان سپری شده: 2676.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 305/2500 تمام شد. زمان سپری شده: 2685.13 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 306/2500 تمام شد. زمان سپری شده: 2693.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 307/2500 تمام شد. زمان سپری شده: 2702.63 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 308/2500 تمام شد. زمان سپری شده: 2711.36 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 309/2500 تمام شد. زمان سپری شده: 2720.17 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 310/2500 تمام شد. زمان سپری شده: 2728.94 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 311/2500 تمام شد. زمان سپری شده: 2737.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 312/2500 تمام شد. زمان سپری شده: 2746.63 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 313/2500 تمام شد. زمان سپری شده: 2755.41 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 314/2500 تمام شد. زمان سپری شده: 2764.18 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 315/2500 تمام شد. زمان سپری شده: 2772.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 316/2500 تمام شد. زمان سپری شده: 2781.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 317/2500 تمام شد. زمان سپری شده: 2790.45 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 318/2500 تمام شد. زمان سپری شده: 2799.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 319/2500 تمام شد. زمان سپری شده: 2808.10 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 320/2500 تمام شد. زمان سپری شده: 2816.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 321/2500 تمام شد. زمان سپری شده: 2825.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 322/2500 تمام شد. زمان سپری شده: 2834.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 323/2500 تمام شد. زمان سپری شده: 2843.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 324/2500 تمام شد. زمان سپری شده: 2851.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 325/2500 تمام شد. زمان سپری شده: 2860.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 326/2500 تمام شد. زمان سپری شده: 2869.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 327/2500 تمام شد. زمان سپری شده: 2878.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 328/2500 تمام شد. زمان سپری شده: 2887.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 329/2500 تمام شد. زمان سپری شده: 2895.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 330/2500 تمام شد. زمان سپری شده: 2904.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 331/2500 تمام شد. زمان سپری شده: 2913.42 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 332/2500 تمام شد. زمان سپری شده: 2922.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 333/2500 تمام شد. زمان سپری شده: 2931.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 334/2500 تمام شد. زمان سپری شده: 2939.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 335/2500 تمام شد. زمان سپری شده: 2948.55 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 336/2500 تمام شد. زمان سپری شده: 2957.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 337/2500 تمام شد. زمان سپری شده: 2966.13 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 338/2500 تمام شد. زمان سپری شده: 2974.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 339/2500 تمام شد. زمان سپری شده: 2983.56 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 340/2500 تمام شد. زمان سپری شده: 2992.34 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 341/2500 تمام شد. زمان سپری شده: 3001.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 342/2500 تمام شد. زمان سپری شده: 3009.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 343/2500 تمام شد. زمان سپری شده: 3018.70 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 344/2500 تمام شد. زمان سپری شده: 3027.48 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 345/2500 تمام شد. زمان سپری شده: 3036.21 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 346/2500 تمام شد. زمان سپری شده: 3045.01 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 347/2500 تمام شد. زمان سپری شده: 3053.75 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 348/2500 تمام شد. زمان سپری شده: 3062.64 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 349/2500 تمام شد. زمان سپری شده: 3071.54 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 350/2500 تمام شد. زمان سپری شده: 3080.34 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 351/2500 تمام شد. زمان سپری شده: 3089.16 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 352/2500 تمام شد. زمان سپری شده: 3097.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 353/2500 تمام شد. زمان سپری شده: 3106.77 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 354/2500 تمام شد. زمان سپری شده: 3115.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 355/2500 تمام شد. زمان سپری شده: 3124.37 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 356/2500 تمام شد. زمان سپری شده: 3133.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 357/2500 تمام شد. زمان سپری شده: 3141.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 358/2500 تمام شد. زمان سپری شده: 3150.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 359/2500 تمام شد. زمان سپری شده: 3159.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 360/2500 تمام شد. زمان سپری شده: 3168.28 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 361/2500 تمام شد. زمان سپری شده: 3177.07 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 362/2500 تمام شد. زمان سپری شده: 3185.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 363/2500 تمام شد. زمان سپری شده: 3194.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 364/2500 تمام شد. زمان سپری شده: 3203.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 365/2500 تمام شد. زمان سپری شده: 3212.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 366/2500 تمام شد. زمان سپری شده: 3221.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 367/2500 تمام شد. زمان سپری شده: 3229.84 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 368/2500 تمام شد. زمان سپری شده: 3238.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 369/2500 تمام شد. زمان سپری شده: 3247.37 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 370/2500 تمام شد. زمان سپری شده: 3256.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 371/2500 تمام شد. زمان سپری شده: 3264.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 372/2500 تمام شد. زمان سپری شده: 3273.76 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 373/2500 تمام شد. زمان سپری شده: 3282.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 374/2500 تمام شد. زمان سپری شده: 3291.24 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 375/2500 تمام شد. زمان سپری شده: 3300.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 376/2500 تمام شد. زمان سپری شده: 3308.90 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 377/2500 تمام شد. زمان سپری شده: 3317.69 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 378/2500 تمام شد. زمان سپری شده: 3326.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 379/2500 تمام شد. زمان سپری شده: 3335.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 380/2500 تمام شد. زمان سپری شده: 3344.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 381/2500 تمام شد. زمان سپری شده: 3352.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 382/2500 تمام شد. زمان سپری شده: 3361.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 383/2500 تمام شد. زمان سپری شده: 3370.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 384/2500 تمام شد. زمان سپری شده: 3379.15 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 385/2500 تمام شد. زمان سپری شده: 3387.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 386/2500 تمام شد. زمان سپری شده: 3396.76 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 387/2500 تمام شد. زمان سپری شده: 3405.53 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 388/2500 تمام شد. زمان سپری شده: 3414.28 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 389/2500 تمام شد. زمان سپری شده: 3423.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 390/2500 تمام شد. زمان سپری شده: 3431.86 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 391/2500 تمام شد. زمان سپری شده: 3440.59 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 392/2500 تمام شد. زمان سپری شده: 3449.41 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 393/2500 تمام شد. زمان سپری شده: 3458.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 394/2500 تمام شد. زمان سپری شده: 3467.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 395/2500 تمام شد. زمان سپری شده: 3475.76 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 396/2500 تمام شد. زمان سپری شده: 3484.56 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 397/2500 تمام شد. زمان سپری شده: 3493.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 398/2500 تمام شد. زمان سپری شده: 3502.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 399/2500 تمام شد. زمان سپری شده: 3510.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 400/2500 تمام شد. زمان سپری شده: 3519.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 401/2500 تمام شد. زمان سپری شده: 3528.52 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 402/2500 تمام شد. زمان سپری شده: 3537.33 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 403/2500 تمام شد. زمان سپری شده: 3546.15 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 404/2500 تمام شد. زمان سپری شده: 3554.90 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 405/2500 تمام شد. زمان سپری شده: 3563.66 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 406/2500 تمام شد. زمان سپری شده: 3572.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 407/2500 تمام شد. زمان سپری شده: 3581.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 408/2500 تمام شد. زمان سپری شده: 3589.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 409/2500 تمام شد. زمان سپری شده: 3598.74 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 410/2500 تمام شد. زمان سپری شده: 3607.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 411/2500 تمام شد. زمان سپری شده: 3616.28 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 412/2500 تمام شد. زمان سپری شده: 3625.07 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 413/2500 تمام شد. زمان سپری شده: 3633.90 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 414/2500 تمام شد. زمان سپری شده: 3642.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 415/2500 تمام شد. زمان سپری شده: 3651.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 416/2500 تمام شد. زمان سپری شده: 3660.31 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 417/2500 تمام شد. زمان سپری شده: 3669.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 418/2500 تمام شد. زمان سپری شده: 3677.82 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 419/2500 تمام شد. زمان سپری شده: 3686.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 420/2500 تمام شد. زمان سپری شده: 3695.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 421/2500 تمام شد. زمان سپری شده: 3704.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 422/2500 تمام شد. زمان سپری شده: 3713.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 423/2500 تمام شد. زمان سپری شده: 3721.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 424/2500 تمام شد. زمان سپری شده: 3730.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 425/2500 تمام شد. زمان سپری شده: 3739.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 426/2500 تمام شد. زمان سپری شده: 3748.07 ثانیه ---
# ...
# --- اجرای 2367/2500 تمام شد. زمان سپری شده: 20834.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2368/2500 تمام شد. زمان سپری شده: 20843.16 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2369/2500 تمام شد. زمان سپری شده: 20852.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2370/2500 تمام شد. زمان سپری شده: 20861.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2371/2500 تمام شد. زمان سپری شده: 20870.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2372/2500 تمام شد. زمان سپری شده: 20879.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2373/2500 تمام شد. زمان سپری شده: 20888.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2374/2500 تمام شد. زمان سپری شده: 20897.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2375/2500 تمام شد. زمان سپری شده: 20906.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2376/2500 تمام شد. زمان سپری شده: 20915.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2377/2500 تمام شد. زمان سپری شده: 20924.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2378/2500 تمام شد. زمان سپری شده: 20933.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2379/2500 تمام شد. زمان سپری شده: 20942.11 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2380/2500 تمام شد. زمان سپری شده: 20951.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2381/2500 تمام شد. زمان سپری شده: 20960.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2382/2500 تمام شد. زمان سپری شده: 20968.86 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2383/2500 تمام شد. زمان سپری شده: 20977.80 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2384/2500 تمام شد. زمان سپری شده: 20986.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2385/2500 تمام شد. زمان سپری شده: 20995.79 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2386/2500 تمام شد. زمان سپری شده: 21004.72 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2387/2500 تمام شد. زمان سپری شده: 21013.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2388/2500 تمام شد. زمان سپری شده: 21022.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2389/2500 تمام شد. زمان سپری شده: 21031.58 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2390/2500 تمام شد. زمان سپری شده: 21040.58 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2391/2500 تمام شد. زمان سپری شده: 21049.53 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2392/2500 تمام شد. زمان سپری شده: 21058.43 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2393/2500 تمام شد. زمان سپری شده: 21067.44 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2394/2500 تمام شد. زمان سپری شده: 21076.34 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2395/2500 تمام شد. زمان سپری شده: 21085.30 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2396/2500 تمام شد. زمان سپری شده: 21094.20 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2397/2500 تمام شد. زمان سپری شده: 21103.12 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2398/2500 تمام شد. زمان سپری شده: 21111.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2399/2500 تمام شد. زمان سپری شده: 21120.94 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2400/2500 تمام شد. زمان سپری شده: 21129.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2401/2500 تمام شد. زمان سپری شده: 21138.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2402/2500 تمام شد. زمان سپری شده: 21147.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2403/2500 تمام شد. زمان سپری شده: 21156.89 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2404/2500 تمام شد. زمان سپری شده: 21165.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2405/2500 تمام شد. زمان سپری شده: 21174.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2406/2500 تمام شد. زمان سپری شده: 21183.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2407/2500 تمام شد. زمان سپری شده: 21192.87 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2408/2500 تمام شد. زمان سپری شده: 21201.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2409/2500 تمام شد. زمان سپری شده: 21210.54 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2410/2500 تمام شد. زمان سپری شده: 21219.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2411/2500 تمام شد. زمان سپری شده: 21228.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2412/2500 تمام شد. زمان سپری شده: 21237.58 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2413/2500 تمام شد. زمان سپری شده: 21246.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2414/2500 تمام شد. زمان سپری شده: 21255.39 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2415/2500 تمام شد. زمان سپری شده: 21264.34 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2416/2500 تمام شد. زمان سپری شده: 21273.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2417/2500 تمام شد. زمان سپری شده: 21282.22 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2418/2500 تمام شد. زمان سپری شده: 21291.16 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2419/2500 تمام شد. زمان سپری شده: 21300.07 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2420/2500 تمام شد. زمان سپری شده: 21308.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2421/2500 تمام شد. زمان سپری شده: 21317.94 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2422/2500 تمام شد. زمان سپری شده: 21326.92 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2423/2500 تمام شد. زمان سپری شده: 21335.89 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2424/2500 تمام شد. زمان سپری شده: 21344.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2425/2500 تمام شد. زمان سپری شده: 21353.78 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2426/2500 تمام شد. زمان سپری شده: 21362.73 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2427/2500 تمام شد. زمان سپری شده: 21371.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2428/2500 تمام شد. زمان سپری شده: 21380.65 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2429/2500 تمام شد. زمان سپری شده: 21389.60 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2430/2500 تمام شد. زمان سپری شده: 21398.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2431/2500 تمام شد. زمان سپری شده: 21407.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2432/2500 تمام شد. زمان سپری شده: 21416.29 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2433/2500 تمام شد. زمان سپری شده: 21425.25 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2434/2500 تمام شد. زمان سپری شده: 21434.25 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2435/2500 تمام شد. زمان سپری شده: 21443.28 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2436/2500 تمام شد. زمان سپری شده: 21452.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2437/2500 تمام شد. زمان سپری شده: 21461.25 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2438/2500 تمام شد. زمان سپری شده: 21470.22 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2439/2500 تمام شد. زمان سپری شده: 21479.23 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2440/2500 تمام شد. زمان سپری شده: 21488.15 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2441/2500 تمام شد. زمان سپری شده: 21497.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2442/2500 تمام شد. زمان سپری شده: 21506.06 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2443/2500 تمام شد. زمان سپری شده: 21515.02 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2444/2500 تمام شد. زمان سپری شده: 21524.03 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2445/2500 تمام شد. زمان سپری شده: 21532.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2446/2500 تمام شد. زمان سپری شده: 21541.97 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2447/2500 تمام شد. زمان سپری شده: 21551.01 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2448/2500 تمام شد. زمان سپری شده: 21559.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2449/2500 تمام شد. زمان سپری شده: 21569.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2450/2500 تمام شد. زمان سپری شده: 21578.04 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2451/2500 تمام شد. زمان سپری شده: 21586.99 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2452/2500 تمام شد. زمان سپری شده: 21596.05 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2453/2500 تمام شد. زمان سپری شده: 21605.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2454/2500 تمام شد. زمان سپری شده: 21613.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2455/2500 تمام شد. زمان سپری شده: 21623.00 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2456/2500 تمام شد. زمان سپری شده: 21631.94 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2457/2500 تمام شد. زمان سپری شده: 21640.88 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2458/2500 تمام شد. زمان سپری شده: 21649.82 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2459/2500 تمام شد. زمان سپری شده: 21658.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2460/2500 تمام شد. زمان سپری شده: 21667.76 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2461/2500 تمام شد. زمان سپری شده: 21676.74 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2462/2500 تمام شد. زمان سپری شده: 21685.61 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2463/2500 تمام شد. زمان سپری شده: 21694.57 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2464/2500 تمام شد. زمان سپری شده: 21703.46 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2465/2500 تمام شد. زمان سپری شده: 21712.50 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2466/2500 تمام شد. زمان سپری شده: 21721.49 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2467/2500 تمام شد. زمان سپری شده: 21730.51 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2468/2500 تمام شد. زمان سپری شده: 21739.52 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2469/2500 تمام شد. زمان سپری شده: 21748.52 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2470/2500 تمام شد. زمان سپری شده: 21757.48 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2471/2500 تمام شد. زمان سپری شده: 21766.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2472/2500 تمام شد. زمان سپری شده: 21775.40 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2473/2500 تمام شد. زمان سپری شده: 21784.35 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2474/2500 تمام شد. زمان سپری شده: 21793.31 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2475/2500 تمام شد. زمان سپری شده: 21802.27 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2476/2500 تمام شد. زمان سپری شده: 21811.24 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2477/2500 تمام شد. زمان سپری شده: 21820.26 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2478/2500 تمام شد. زمان سپری شده: 21829.32 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2479/2500 تمام شد. زمان سپری شده: 21838.29 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2480/2500 تمام شد. زمان سپری شده: 21847.28 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2481/2500 تمام شد. زمان سپری شده: 21856.25 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2482/2500 تمام شد. زمان سپری شده: 21865.23 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2483/2500 تمام شد. زمان سپری شده: 21874.19 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2484/2500 تمام شد. زمان سپری شده: 21883.14 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2485/2500 تمام شد. زمان سپری شده: 21892.08 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2486/2500 تمام شد. زمان سپری شده: 21901.05 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2487/2500 تمام شد. زمان سپری شده: 21910.09 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2488/2500 تمام شد. زمان سپری شده: 21919.04 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2489/2500 تمام شد. زمان سپری شده: 21927.98 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2490/2500 تمام شد. زمان سپری شده: 21936.95 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2491/2500 تمام شد. زمان سپری شده: 21945.93 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2492/2500 تمام شد. زمان سپری شده: 21954.91 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2493/2500 تمام شد. زمان سپری شده: 21963.85 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2494/2500 تمام شد. زمان سپری شده: 21972.83 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2495/2500 تمام شد. زمان سپری شده: 21981.78 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2496/2500 تمام شد. زمان سپری شده: 21990.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2497/2500 تمام شد. زمان سپری شده: 21999.67 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2498/2500 تمام شد. زمان سپری شده: 22008.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2499/2500 تمام شد. زمان سپری شده: 22017.71 ثانیه ---
# Initialized 24200 particles for Shock Tube problem.
# --- اجرای 2500/2500 تمام شد. زمان سپری شده: 22026.66 ثانیه ---
# /tmp/ipython-input-5-3717327472.py:429: RuntimeWarning: Mean of empty slice
#   averaged_results[t][key] = np.nanmean(np.array(all_data_for_t_and_key), axis=0)
# /tmp/ipython-input-5-3717327472.py:429: RuntimeWarning: Mean of empty slice
#   averaged_results[t][key] = np.nanmean(np.array(all_data_for_t_and_key), axis=0)
# /tmp/ipython-input-5-3717327472.py:429: RuntimeWarning: Mean of empty slice
#   averaged_results[t][key] = np.nanmean(np.array(all_data_for_t_and_key), axis=0)
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
